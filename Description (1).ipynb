# %% [markdown]
# ## PROMPT
# #### Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.

# %% [markdown]
# Dallas-Fort Worth has more restaurants per capita than anywhere in the United States. Their cuisine is part of the Texan experience. What comes to mind when someone mentions Texan Cuisine is barbeque.One of the top barbecue restaurants in Dallas is the Pecan Lodge. For most Pecan Lodge is synonymous with BBQ. Despite their success they only have one location on Main Street.

# %% [markdown]
# ### Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.

# %% [markdown]
# In this project we will try to find the best potential location to expand their business. We will try to find a location that will gather the most attention from tourists,to give them the opportunity to have a real Texan experience.
# While we look at popular tourist locations, we will also look for any barbeque restaurants in the immediate vicinity.
# We will analyze data for the most optimal location based on the criteria.The data will show us some locations that hold the most precedence for a second location.
